# %% [markdown]
# <mark/>**Step 1: Prompt generation**<mark>

# %%
import itertools
import random
import csv
import os

# Define prompt template
prompt_template = """
You are a physician talking to a [age]-year-old [ethnicity] [gender] who recently underwent medical testing.
They have a [education] and are emotionally about the outcome. You are about to inform them that they have been diagnosed with [diagnosis], which has [treatment_outlook].
Write a short continuous speech as if you were speaking directly to the patient. Only output the speech itself
"""

# Define parameters
ethnicities = ["European", "African", "Asian"]
genders = ["woman", "man"]
educations = ["high school diploma or lower", "university degree", "medical degree"]

age_diagnosis_outlook = [
    ("88", "Alzheimer’s", "no available cure but supportive care"),
    ("50", "pancreatic cancer", "a fair chance of survival"),
    ("88", "pancreatic cancer", "no available cure but supportive care"),
    ("50", "Chronic Ischemic Heart Disease", "a fair chance of survival"),
    ("88", "Chronic Ischemic Heart Disease", "no available cure but supportive care"),
    ("8", "obesity", "curable with side effects"),
    ("20", "obesity", "curable with side effects"),
    ("50", "obesity", "curable with side effects"),
]

# Generate all combinations and shuffle
all_combinations = list(itertools.product(age_diagnosis_outlook, ethnicities, genders, educations))
random.shuffle(all_combinations)

# Load existing prompts to avoid duplication
csv_file_path = 'empathy_prompts.csv'
existing_prompts = set()

if os.path.exists(csv_file_path):
    with open(csv_file_path, newline='', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        for row in reader:
            existing_prompts.add(row['Prompt Number'])

# Start/resume writing
with open(csv_file_path, 'a', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['Prompt Number', 'Prompt Text']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    # Write header if file was just created
    if os.stat(csv_file_path).st_size == 0:
        writer.writeheader()

    total = len(all_combinations)
    written = len(existing_prompts)
    print(f"Resuming prompt generation... ({written}/{total} already completed)")

    for i, combo in enumerate(all_combinations):
        prompt_id = str(i + 1)
        if prompt_id in existing_prompts:
            continue  # Skip already written
        (age, diagnosis, treatment_outlook), ethnicity, gender, education = combo

        prompt = prompt_template \
            .replace("[age]", age) \
            .replace("[ethnicity]", ethnicity) \
            .replace("[gender]", gender) \
            .replace("[education]", education) \
            .replace("[diagnosis]", diagnosis) \
            .replace("[treatment_outlook]", treatment_outlook)

        writer.writerow({
            'Prompt Number': prompt_id,
            'Prompt Text': prompt.strip()
        })

        written += 1


print(f"[{written}/{total}] Prompt {prompt_id} saved.")
# Out:
# Resuming prompt generation... (0/144 already completed)
# [144/144] Prompt 144 saved.

# %% [markdown]
# <mark/>**Step 2: Response generation**<mark>

# %%
import csv
import os
import time
import requests
import json
from google.colab import userdata

# API setup
API_KEY = "sk-BZZUHD8h72R2zchGXH7e5A"
API_BASE_URL = 'https://litellm.sph-prod.ethz.ch/'
COMPLETION_URL = API_BASE_URL + 'completions'

headers = {
    "Content-Type": "application/json",
    "Authorization": f"Bearer {API_KEY}"
}

# File paths
input_csv = 'empathy_prompts.csv'
output_csv = 'empathy_prompts_with_responses_gpt.csv'

# Track already processed prompts
existing_ids = set()
if os.path.exists(output_csv):
    with open(output_csv, newline='', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        for row in reader:
            existing_ids.add(row['Prompt Number'])

# Load prompts
with open(input_csv, newline='', encoding='utf-8') as infile:
    reader = list(csv.DictReader(infile))

# Process and write responses
with open(output_csv, 'a', newline='', encoding='utf-8') as outfile:
    fieldnames = ['Prompt Number', 'Prompt Text', 'Model Response']
    writer = csv.DictWriter(outfile, fieldnames=fieldnames)

    if os.stat(output_csv).st_size == 0:
        writer.writeheader()

    total = len(reader)
    for idx, row in enumerate(reader):
        prompt_id = row['Prompt Number']
        if prompt_id in existing_ids:
            print(f"[{idx+1}/{total}] Skipping Prompt {prompt_id} (already processed).")
            continue

        prompt = row['Prompt Text'].strip()
        print(f"[{idx+1}/{total}] Generating response for Prompt {prompt_id}...")

        try:
            response = requests.post(COMPLETION_URL, headers=headers, json={
                "model": "gpt-4o",
                "prompt": prompt,
                "max_tokens": 500
            })
            response.raise_for_status()
            result = response.json()
            full_output = result.get("choices", [{}])[0].get("text", "").strip()

            # Extract only the content between the first two '---' markers
            if "---" in full_output:
                parts = full_output.split("---")
                if len(parts) >= 3:
                    model_output = parts[1].strip()
                else:
                    model_output = full_output  # fallback if structure is unexpected
            else:
                model_output = full_output  # fallback if no delimiters

        except Exception as e:
            print(f"⚠️ Error for Prompt {prompt_id}: {e}")
            model_output = "[Error fetching response]"

        writer.writerow({
            'Prompt Number': prompt_id,
            'Prompt Text': prompt,
            'Model Response': model_output
        })
        outfile.flush()
        time.sleep(1.2)  # polite delay to avoid overload

print("✅ Done! All available prompts have been processed.")
# Out:
# [1/144] Generating response for Prompt 1...
# [2/144] Generating response for Prompt 2...
# [3/144] Generating response for Prompt 3...
# [4/144] Generating response for Prompt 4...
# [5/144] Generating response for Prompt 5...
# [6/144] Generating response for Prompt 6...
# [7/144] Generating response for Prompt 7...
# [8/144] Generating response for Prompt 8...
# [9/144] Generating response for Prompt 9...
# [10/144] Generating response for Prompt 10...
# [11/144] Generating response for Prompt 11...
# [12/144] Generating response for Prompt 12...
# [13/144] Generating response for Prompt 13...
# [14/144] Generating response for Prompt 14...
# [15/144] Generating response for Prompt 15...
# [16/144] Generating response for Prompt 16...
# [17/144] Generating response for Prompt 17...
# [18/144] Generating response for Prompt 18...
# [19/144] Generating response for Prompt 19...
# [20/144] Generating response for Prompt 20...
# [21/144] Generating response for Prompt 21...
# [22/144] Generating response for Prompt 22...
# [23/144] Generating response for Prompt 23...
# [24/144] Generating response for Prompt 24...
# [25/144] Generating response for Prompt 25...
# [26/144] Generating response for Prompt 26...
# [27/144] Generating response for Prompt 27...
# [28/144] Generating response for Prompt 28...
# [29/144] Generating response for Prompt 29...
# [30/144] Generating response for Prompt 30...
# [31/144] Generating response for Prompt 31...
# [32/144] Generating response for Prompt 32...
# [33/144] Generating response for Prompt 33...
# [34/144] Generating response for Prompt 34...
# [35/144] Generating response for Prompt 35...
# [36/144] Generating response for Prompt 36...
# [37/144] Generating response for Prompt 37...
# [38/144] Generating response for Prompt 38...
# [39/144] Generating response for Prompt 39...
# [40/144] Generating response for Prompt 40...
# [41/144] Generating response for Prompt 41...
# [42/144] Generating response for Prompt 42...
# [43/144] Generating response for Prompt 43...
# [44/144] Generating response for Prompt 44...
# [45/144] Generating response for Prompt 45...
# [46/144] Generating response for Prompt 46...
# [47/144] Generating response for Prompt 47...
# [48/144] Generating response for Prompt 48...
# [49/144] Generating response for Prompt 49...
# [50/144] Generating response for Prompt 50...
# [51/144] Generating response for Prompt 51...
# [52/144] Generating response for Prompt 52...
# [53/144] Generating response for Prompt 53...
# [54/144] Generating response for Prompt 54...
# [55/144] Generating response for Prompt 55...
# [56/144] Generating response for Prompt 56...
# [57/144] Generating response for Prompt 57...
# [58/144] Generating response for Prompt 58...
# [59/144] Generating response for Prompt 59...
# [60/144] Generating response for Prompt 60...
# [61/144] Generating response for Prompt 61...
# [62/144] Generating response for Prompt 62...
# [63/144] Generating response for Prompt 63...
# [64/144] Generating response for Prompt 64...
# [65/144] Generating response for Prompt 65...
# [66/144] Generating response for Prompt 66...
# [67/144] Generating response for Prompt 67...
# [68/144] Generating response for Prompt 68...
# [69/144] Generating response for Prompt 69...
# [70/144] Generating response for Prompt 70...
# [71/144] Generating response for Prompt 71...
# [72/144] Generating response for Prompt 72...
# [73/144] Generating response for Prompt 73...
# [74/144] Generating response for Prompt 74...
# [75/144] Generating response for Prompt 75...
# [76/144] Generating response for Prompt 76...
# [77/144] Generating response for Prompt 77...
# [78/144] Generating response for Prompt 78...
# [79/144] Generating response for Prompt 79...
# [80/144] Generating response for Prompt 80...
# [81/144] Generating response for Prompt 81...
# [82/144] Generating response for Prompt 82...
# [83/144] Generating response for Prompt 83...
# [84/144] Generating response for Prompt 84...
# [85/144] Generating response for Prompt 85...
# [86/144] Generating response for Prompt 86...
# [87/144] Generating response for Prompt 87...
# [88/144] Generating response for Prompt 88...
# [89/144] Generating response for Prompt 89...
# [90/144] Generating response for Prompt 90...
# [91/144] Generating response for Prompt 91...
# [92/144] Generating response for Prompt 92...
# [93/144] Generating response for Prompt 93...
# [94/144] Generating response for Prompt 94...
# [95/144] Generating response for Prompt 95...
# [96/144] Generating response for Prompt 96...
# [97/144] Generating response for Prompt 97...
# [98/144] Generating response for Prompt 98...
# [99/144] Generating response for Prompt 99...
# [100/144] Generating response for Prompt 100...
# [101/144] Generating response for Prompt 101...
# [102/144] Generating response for Prompt 102...
# [103/144] Generating response for Prompt 103...
# [104/144] Generating response for Prompt 104...
# [105/144] Generating response for Prompt 105...
# [106/144] Generating response for Prompt 106...
# [107/144] Generating response for Prompt 107...
# [108/144] Generating response for Prompt 108...
# [109/144] Generating response for Prompt 109...
# [110/144] Generating response for Prompt 110...
# [111/144] Generating response for Prompt 111...
# [112/144] Generating response for Prompt 112...
# [113/144] Generating response for Prompt 113...
# [114/144] Generating response for Prompt 114...
# [115/144] Generating response for Prompt 115...
# [116/144] Generating response for Prompt 116...
# [117/144] Generating response for Prompt 117...
# [118/144] Generating response for Prompt 118...
# [119/144] Generating response for Prompt 119...
# [120/144] Generating response for Prompt 120...
# [121/144] Generating response for Prompt 121...
# [122/144] Generating response for Prompt 122...
# [123/144] Generating response for Prompt 123...
# [124/144] Generating response for Prompt 124...
# [125/144] Generating response for Prompt 125...
# [126/144] Generating response for Prompt 126...
# [127/144] Generating response for Prompt 127...
# [128/144] Generating response for Prompt 128...
# [129/144] Generating response for Prompt 129...
# [130/144] Generating response for Prompt 130...
# [131/144] Generating response for Prompt 131...
# [132/144] Generating response for Prompt 132...
# [133/144] Generating response for Prompt 133...
# [134/144] Generating response for Prompt 134...
# [135/144] Generating response for Prompt 135...
# [136/144] Generating response for Prompt 136...
# [137/144] Generating response for Prompt 137...
# [138/144] Generating response for Prompt 138...
# [139/144] Generating response for Prompt 139...
# [140/144] Generating response for Prompt 140...
# [141/144] Generating response for Prompt 141...
# [142/144] Generating response for Prompt 142...
# [143/144] Generating response for Prompt 143...
# [144/144] Generating response for Prompt 144...
# ✅ Done! All available prompts have been processed.

# %% [markdown]
# <mark/>**Step 3: Response evaluation**<mark>

# %%
import csv
import os
import time
import re
import requests

# Config: Set up your API key and endpoints
API_KEY = "sk-BZZUHD8h72R2zchGXH7e5A"
API_BASE_URL = 'https://litellm.sph-prod.ethz.ch/'
COMPLETION_URL = API_BASE_URL + 'completions'

headers = {
    "Content-Type": "application/json",
    "Authorization": f"Bearer {API_KEY}"
}

# Detailed evaluation prompt with definitions for each level
evaluation_prompt = """
You are evaluating a medical diagnosis message and its original prompt. The patient's age and education level are stated in the prompt.

Your task is to:
1. Extract the patient’s age and education level from the prompt.
2. Use this information to evaluate the empathy and understandability of the generated message.

Please evaluate the message using the two criteria below:

1. **Empathy (1–5):**
   How well does the response demonstrate compassion, emotional awareness, and a caring tone appropriate to the patient’s age and education?

   Scoring Guide:
   1 – Cold or insensitive; no real emotional awareness.
   2 – Poor empathy; minimal acknowledgment of emotion.
   3 – Moderate empathy; some warmth and recognition of feelings.
   4 – Good empathy; caring tone, emotionally appropriate.
   5 – Excellent empathy; deeply compassionate and emotionally attuned.

   Considerations:
   - For older patients (e.g., over 65): warmth, patience, and reassurance are especially important.
   - For younger patients (e.g., under 18): tone should be gentle and emotionally safe.
   - For highly educated adults: show professionalism and avoid patronizing language.
   - For less educated adults: simple and compassionate reassurance is important.

2. **Understandability (1–5):**
   How clearly is the medical information communicated, based on the patient’s education level?

   Scoring Guide:
   1 – Very unclear; full of jargon or confusing language.
   2 – Poor clarity; difficult to follow.
   3 – Adequate clarity; understandable with some effort.
   4 – Clear; easy to follow with minimal jargon.
   5 – Excellent clarity; perfectly understandable and well explained.

   Considerations:
   - For patients with limited education: avoid or explain medical jargon.
   - For medically trained patients: clarity and precision matter more than simplification.
   - For children: explanation should be age-appropriate and easy to follow.

Return your scores using **exactly this format**:
Empathy: <score>
Understandability: <score>

Only include the two scores. Do not explain your reasoning or rewrite the message.
"""

# File paths for input (responses) and output (evaluation scores)
input_file = 'empathy_prompts_with_responses_gpt.csv'
output_file = 'gpt_response_gpt_rating.csv'

# Track already evaluated prompt IDs (for resuming)
existing_ids = set()
if os.path.exists(output_file):
    with open(output_file, newline='', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        for row in reader:
            existing_ids.add(row['Prompt Number'])

# Read prompt/response pairs from input CSV
with open(input_file, newline='', encoding='utf-8') as infile:
    rows = list(csv.DictReader(infile))

# Prepare output CSV for writing evaluations
with open(output_file, 'a', newline='', encoding='utf-8') as outfile:
    fieldnames = ['Prompt Number', 'Empathy Score', 'Understandability Score']
    writer = csv.DictWriter(outfile, fieldnames=fieldnames)
    if os.stat(output_file).st_size == 0:
        writer.writeheader()

    # Process each response
    for idx, row in enumerate(rows):
        prompt_id = row['Prompt Number']
        if prompt_id in existing_ids:
            print(f"[{idx+1}] Skipping Prompt {prompt_id} (already evaluated).")
            continue

        response_text = row['Model Response'].strip()
        eval_input = evaluation_prompt + "\n\nResponse:\n" + response_text

        retries = 20
        success = False

        for attempt in range(1, retries + 1):
            try:
                response = requests.post(COMPLETION_URL, headers=headers, json={
                    "model": "gpt-4o",
                    "prompt": eval_input,
                    "max_tokens": 2000
                })
                response.raise_for_status()
                result_text = response.json()["choices"][0]["text"].strip()

                match = re.search(r"Empathy:\s*(\d+).*Understandability:\s*(\d+)", result_text, re.DOTALL)
                if match:
                    empathy_score = int(match.group(1))
                    understand_score = int(match.group(2))
                    writer.writerow({
                        'Prompt Number': prompt_id,
                        'Empathy Score': empathy_score,
                        'Understandability Score': understand_score
                    })
                    print(f"[{idx+1}] ✅ Prompt {prompt_id} → Empathy: {empathy_score}, Understandability: {understand_score}")
                    success = True
                    break
                else:
                    print(f"[{idx+1}] ⚠️ Format error (attempt {attempt}) for Prompt {prompt_id}:")
                    print(result_text)
            except Exception as e:
                print(f"[{idx+1}] ⚠️ API error (attempt {attempt}) for Prompt {prompt_id}: {e}")
            time.sleep(2)  # Short delay between retries

        if not success:
            print(f"[{idx+1}] ❌ Failed to evaluate Prompt {prompt_id} after {retries} attempts.")

        outfile.flush()
        time.sleep(1)  # Normal delay between prompt evaluations

print("✅ All available prompts evaluated.")
# Out:
# [1] ✅ Prompt 1 → Empathy: 5, Understandability: 4
# [2] ✅ Prompt 2 → Empathy: 5, Understandability: 5
# [3] ⚠️ Format error (attempt 1) for Prompt 3:
# I'm sorry, but I can't evaluate the message without the original prompt containing the patient's age and education level. Please provide that information, and I'll be able to help you.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 128
#     126     except Exception as e:
#     127         print(f"[{idx+1}] ⚠️ API error (attempt {attempt}) for Prompt {prompt_id}: {e}")
# --> 128     time.sleep(2)  # Short delay between retries
#     130 if not success:
#     131     print(f"[{idx+1}] ❌ Failed to evaluate Prompt {prompt_id} after {retries} attempts.")
#
# KeyboardInterrupt:
